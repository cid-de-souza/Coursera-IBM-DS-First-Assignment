# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Cid Carvalho de Souza**

# %% [markdown]
# Current occupation: university professor

# %% [markdown]
# *I am interested in data science because several of these techniques can help me in my research.*

# %% [markdown]
# *Also,  I believe that having some proficiency in DS and ML is critical to any professional these days.*

# %% [markdown]
# ### Simple code to compute the area of the rectangles with integral width (w) and height (h) varying from 1 to 3

# %%
for w in range(1,4):
    for h in range(1,4):
        print("- The area of a rectangle of width %d and height %d is %d" % (w,h,w*h))
# Out:
# - The area of a rectangle of width 1 and height 1 is 1
# - The area of a rectangle of width 1 and height 2 is 2
# - The area of a rectangle of width 1 and height 3 is 3
# - The area of a rectangle of width 2 and height 1 is 2
# - The area of a rectangle of width 2 and height 2 is 4
# - The area of a rectangle of width 2 and height 3 is 6
# - The area of a rectangle of width 3 and height 1 is 3
# - The area of a rectangle of width 3 and height 2 is 6
# - The area of a rectangle of width 3 and height 3 is 9

# %% [markdown]
# #### Table with features used in this notebook:
#
# | Feature |  Included |
# | :------- | :--------: |
# | horizontal rule | |
# | bulleted list | &check; |
# | numbered list | &check; |
# | tables | &check; |
# | hyperlinks | &check; |
# | images | |
# | code/syntax highlighting | &check;|
# | blocked quotes | |
# | strikethrough | &check;|
#
# #### Numbered list of features not present in this page with `strikethrough`:
# 1. ~~horizontal rule~~
# 2. ~~bulleted list~~
# 3. ~~images~~
# 4. ~~code/syntax highlighting~~
# 5. ~~blocked quotes~~
#
# #### Use of hyperlynks and bulletted lists:
#
# * Here is a [link](https://openmoji.org) where you have free emojis available.
